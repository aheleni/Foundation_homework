# %% [markdown]
# # Homework 6, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
type(pd.read_csv('craftcans.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('craftcans.csv')

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer        object
# Brewery     object
# Location    object
# Style       object
# Size        object
# ABV         object
# IBUs        object
# dtype: object

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df.groupby(by='Brewery').count().head(10)
# Out:
#                            Beer  Location  Style  Size  ABV  IBUs
# Brewery
# 10 Barrel Brewing Company     1         1      1     1    1     1
# 18th Street Brewery          14        14     14    14   14    14
# 2 Towns Ciderhouse            4         4      4     4    4     4
# 21st Amendment Brewery       20        20     20    20   20    20
# 3 Daughters Brewing           3         3      3     3    3     3
# 4 Hands Brewing Company       8         8      8     8    8     8
# 450 North Brewing Company     7         7      7     7    7     7
# 7 Seas Brewing Company        4         4      4     4    4     4
# 7venth Sun                    1         1      1     1    1     1
# AC Golden Brewing Company     2         2      2     2    2     2

# %%
df.Brewery.value_counts().head(10)
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# 21st Amendment Brewery        20
# Great Crescent Brewery        20
# Bonfire Brewing Company       19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.ABV.value_counts()
# Out:
# 5.00%     215
# 5.50%     158
# 6.00%     125
# 6.50%     123
# 5.20%     107
# 7.00%      92
# 4.50%      89
# 4.80%      72
# 5.80%      66
# 5.60%      66
# 5.10%      62
# 5.30%      60
# 6.20%      59
# 4.90%      59
# 4.70%      57
# 8.00%      57
# 5.70%      52
# 6.80%      52
# 5.40%      50
# 7.50%      43
# 6.30%      38
# 4.00%      38
# 4.20%      38
# 7.20%      37
# 9.90%      35
# 5.90%      34
# 6.90%      32
# 4.60%      32
# 8.50%      26
# 6.70%      25
#          ...
# 4.10%       9
# 9.50%       9
# 7.40%       8
# 8.30%       8
# 7.90%       7
# 8.80%       6
# 3.80%       6
# 3.50%       6
# 9.60%       5
# 9.30%       5
# 9.70%       5
# 7.60%       5
# 8.10%       4
# 3.70%       4
# 8.60%       4
# 9.80%       3
# 9.10%       3
# 8.40%       3
# 3.20%       3
# 8.90%       2
# 2.70%       2
# 12.00%      1
# 12.80%      1
# 2.80%       1
# 10.40%      1
# 9.40%       1
# 3.40%       1
# 0.10%       1
# 10.00%      1
# 12.50%      1
# Name: ABV, Length: 74, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
df.ABV
# Out:
# 0        4.50%
# 1        4.90%
# 2        4.80%
# 3        6.00%
# 4        6.00%
# 5        5.60%
# 6        8.00%
# 7       12.50%
# 8        7.70%
# 9        4.20%
# 10       5.00%
# 11       6.60%
# 12       4.00%
# 13       5.50%
# 14       7.60%
# 15       5.10%
# 16       6.50%
# 17       6.00%
# 18       5.00%
# 19       5.20%
# 20       4.80%
# 21       7.20%
# 22       6.70%
# 23       4.90%
# 24       8.00%
# 25       7.50%
# 26       6.00%
# 27       8.00%
# 28       6.30%
# 29       5.80%
#          ...
# 2386     5.70%
# 2387     6.20%
# 2388     4.90%
# 2389     9.90%
# 2390     6.20%
# 2391     5.80%
# 2392     5.20%
# 2393     8.50%
# 2394     7.00%
# 2395     5.30%
# 2396     5.60%
# 2397     4.90%
# 2398     5.10%
# 2399     4.00%
# 2400     5.50%
# 2401     5.10%
# 2402     5.10%
# 2403     9.70%
# 2404     5.10%
# 2405     6.70%
# 2406     6.20%
# 2407     8.30%
# 2408     7.00%
# 2409     4.90%
# 2410     9.90%
# 2411     5.30%
# 2412     9.90%
# 2413     8.00%
# 2414     8.70%
# 2415     6.50%
# Name: ABV, Length: 2416, dtype: object

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# - *Tip: `.replace` is used for replacing ENTIRE cells, while `.str.replace` is useful for replacing PARTS of cells (see my New York example)*

# %%
df['ABV'] = df.ABV.str.replace('%', ' ')

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df.dtypes
# Out:
# Beer        object
# Brewery     object
# Location    object
# Style       object
# Size        object
# ABV         object
# IBUs        object
# dtype: object

# %%
df['ABV']=df['ABV'].astype(float)

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs         object
# dtype: object

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs         object
# dtype: object

# %%
df.ABV.describe()
# Out:
# count    2348.000000
# mean        5.977342
# std         1.354173
# min         0.100000
# 25%         5.000000
# 50%         5.600000
# 75%         6.700000
# max        12.800000
# Name: ABV, dtype: float64

# %%
df.groupby(by='Beer').ABV.plot(kind='bar')
# Out:
# Beer
# #001 Golden Amber Lager                   AxesSubplot(0.125,0.125;0.775x0.755)
# #002 American I.P.A.                      AxesSubplot(0.125,0.125;0.775x0.755)
# #003 Brown & Robust Porter                AxesSubplot(0.125,0.125;0.775x0.755)
# #004 Session I.P.A.                       AxesSubplot(0.125,0.125;0.775x0.755)
# #9                                        AxesSubplot(0.125,0.125;0.775x0.755)
# (12 oz.)                                  AxesSubplot(0.125,0.125;0.775x0.755)
# (16 oz.) (2010)                           AxesSubplot(0.125,0.125;0.775x0.755)
# (24 oz.)                                  AxesSubplot(0.125,0.125;0.775x0.755)
# 077XX                                     AxesSubplot(0.125,0.125;0.775x0.755)
# 10 Degrees of Separation                  AxesSubplot(0.125,0.125;0.775x0.755)
# 10 Ton                                    AxesSubplot(0.125,0.125;0.775x0.755)
# 113 IPA                                   AxesSubplot(0.125,0.125;0.775x0.755)
# 11th Hour IPA                             AxesSubplot(0.125,0.125;0.775x0.755)
# 12 Man Pale Ale                           AxesSubplot(0.125,0.125;0.775x0.755)
# 12 oz.                                    AxesSubplot(0.125,0.125;0.775x0.755)
# 12th Round                                AxesSubplot(0.125,0.125;0.775x0.755)
# 13 Rebels ESB                             AxesSubplot(0.125,0.125;0.775x0.755)
# 1327 Pod's ESB                            AxesSubplot(0.125,0.125;0.775x0.755)
# 1335 Wicked Snout                         AxesSubplot(0.125,0.125;0.775x0.755)
# 1492                                      AxesSubplot(0.125,0.125;0.775x0.755)
# 14° ESB                                   AxesSubplot(0.125,0.125;0.775x0.755)
# 1554 Black Lager                          AxesSubplot(0.125,0.125;0.775x0.755)
# 15th Anniversary Abbey Ale (2012)         AxesSubplot(0.125,0.125;0.775x0.755)
# 1800 Big Log Wheat (2012)                 AxesSubplot(0.125,0.125;0.775x0.755)
# 1811 Lager                                AxesSubplot(0.125,0.125;0.775x0.755)
# 1836                                      AxesSubplot(0.125,0.125;0.775x0.755)
# 1881 California Red                       AxesSubplot(0.125,0.125;0.775x0.755)
# 1881 California Red Ale                   AxesSubplot(0.125,0.125;0.775x0.755)
# 18th Anniversary Gose                     AxesSubplot(0.125,0.125;0.775x0.755)
# 1916 Shore Shiver                         AxesSubplot(0.125,0.125;0.775x0.755)
#                                                           ...
# Wooden Rooster                            AxesSubplot(0.125,0.125;0.775x0.755)
# Woolybugger Wheat                         AxesSubplot(0.125,0.125;0.775x0.755)
# Workers Comp Saison                       AxesSubplot(0.125,0.125;0.775x0.755)
# Working for the Weekend                   AxesSubplot(0.125,0.125;0.775x0.755)
# Worthy IPA                                AxesSubplot(0.125,0.125;0.775x0.755)
# Worthy IPA (2013)                         AxesSubplot(0.125,0.125;0.775x0.755)
# Worthy Pale                               AxesSubplot(0.125,0.125;0.775x0.755)
# Wrath of Pele                             AxesSubplot(0.125,0.125;0.775x0.755)
# Wynkoop Pumpkin Ale                       AxesSubplot(0.125,0.125;0.775x0.755)
# Wynona's Big Brown Ale                    AxesSubplot(0.125,0.125;0.775x0.755)
# Wyoming Pale Ale                          AxesSubplot(0.125,0.125;0.775x0.755)
# Yabba Dhaba Chai Tea Porter               AxesSubplot(0.125,0.125;0.775x0.755)
# Yard Sale Amber Ale                       AxesSubplot(0.125,0.125;0.775x0.755)
# Yard Sale Winter Lager                    AxesSubplot(0.125,0.125;0.775x0.755)
# Yellow Collar                             AxesSubplot(0.125,0.125;0.775x0.755)
# Yellow Wolf Imperial IPA                  AxesSubplot(0.125,0.125;0.775x0.755)
# Yellowstone Golden Ale                    AxesSubplot(0.125,0.125;0.775x0.755)
# Yeti Imperial Stout                       AxesSubplot(0.125,0.125;0.775x0.755)
# Yo Soy Un Berliner                        AxesSubplot(0.125,0.125;0.775x0.755)
# Yonder Bock                               AxesSubplot(0.125,0.125;0.775x0.755)
# Yoshi's Nectar                            AxesSubplot(0.125,0.125;0.775x0.755)
# You're My Boy, Blue                       AxesSubplot(0.125,0.125;0.775x0.755)
# Yunkin' Punkin'                           AxesSubplot(0.125,0.125;0.775x0.755)
# Zaison                                    AxesSubplot(0.125,0.125;0.775x0.755)
# Zaison (2012)                             AxesSubplot(0.125,0.125;0.775x0.755)
# Zen                                       AxesSubplot(0.125,0.125;0.775x0.755)
# Zombie Monkie                             AxesSubplot(0.125,0.125;0.775x0.755)
# Zonker Stout                              AxesSubplot(0.125,0.125;0.775x0.755)
# oSKAr the G'Rauch                         AxesSubplot(0.125,0.125;0.775x0.755)
# the Kimmie, the Yink and the Holy Gose    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: ABV, Length: 2306, dtype: object

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
df[df.ABV.isna()]
# Out:
#                                         Beer                          Brewery  \
# 94                                   Bastian       James Page Brewing Company
# 199                          Professor Black                 Blue Owl Brewing
# 200                              Little Boss                 Blue Owl Brewing
# 201                               Van Dayum!                 Blue Owl Brewing
# 202                            Spirit Animal                 Blue Owl Brewing
# 217                            U. P. Witbier         Keweenaw Brewing Company
# 307                               Fat Paczki                   Brewery Vivant
# 308                       Earth-Like Planets                   Brewery Vivant
# 324                              Royal Lager           Weston Brewing Company
# 344                         O’Malley’s Stout           Weston Brewing Company
# 346         O’Malley’s Irish Style Cream Ale           Weston Brewing Company
# 365                            Fort Pitt Ale        Fort Pitt Brewing Company
# 476                          Special Release              Cedar Creek Brewery
# 727                              30 Min Coma         Sun King Brewing Company
# 871                             The CROWLER™              Oskar Blues Brewery
# 877                     CAN'D AID Foundation              Oskar Blues Brewery
# 883                         Appreciation Ale   Iron Hill Brewery & Restaurant
# 914                                Icey.P.A.              Oskar Blues Brewery
# 916                                Birth IPA              Oskar Blues Brewery
# 942          Cal and Co. Black Cherry Porter  Rochester Mills Brewing Company
# 1897             16 oz.  NaN  Does not apply
# 1950             12 oz.  NaN  Does not apply
# 2025                NaN  NaN             NaN
# 2063             16 oz.  NaN  Does not apply
# 2066             12 oz.  NaN  Does not apply
# 2079             12 oz.  NaN  Does not apply
# 2081             16 oz.  NaN  Does not apply
# 2118             16 oz.  NaN  Does not apply
# 2119             16 oz.  NaN  Does not apply
# 2120             16 oz.  NaN  Does not apply
# 2121             16 oz.  NaN  Does not apply
# 2122             16 oz.  NaN  Does not apply
# 2160                NaN  NaN             NaN
# 2189             12 oz.  NaN  Does not apply
# 2216             12 oz.  NaN  Does not apply
# 2226                NaN  NaN             NaN
# 2238             12 oz.  NaN  Does not apply
# 2243             16 oz.  NaN  Does not apply
# 2247             12 oz.  NaN  Does not apply
# 2276                NaN  NaN             NaN
# 2288             12 oz.  NaN  Does not apply
# 2303             12 oz.  NaN  Does not apply
# 2352             12 oz.  NaN  Does not apply
# 2355             12 oz.  NaN  Does not apply
# 2356             12 oz.  NaN  Does not apply
# 2357             12 oz.  NaN  Does not apply
# 2358             12 oz.  NaN  Does not apply
# 2359             12 oz.  NaN  Does not apply
# 2374                NaN  NaN             NaN
# 2376                NaN  NaN             NaN
#
# [68 rows x 7 columns]

# %%
df.ABV.isna().sum()
# Out:
# 68

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %%
Brooklyn = df[df.Location == 'Brooklyn, NY'].Beer.value_counts().sum()

# %%
df.Beer.count()
# Out:
# 2416

# %%
Brooklyn / df.Beer.count() * 100
# Out:
# 1.5728476821192054

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df.groupby(by='Location').count().head(10)
# Out:
#                     Beer  Brewery  Style  Size  ABV  IBUs
# Location
# Abingdon, VA           1        1      1     1    1     1
# Abita Springs, LA      3        3      3     3    3     3
# Ada, MI                1        1      1     1    1     1
# Afton, VA              4        4      4     4    4     4
# Airway Heights, WA     5        5      5     5    5     5
# Albuquerque, NM        7        7      7     7    7     7
# Alpine, TX             5        5      5     5    5     5
# Anchorage, AK         15       15     15    15   15    15
# Angola, IN             4        4      4     4    4     4
# Ann Arbor, MI          1        1      1     1    1     1

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df.Location == 'Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1366                    American IPA             12 oz.   2.7  Does not apply
# 1373    English India Pale Ale (IPA)             16 oz.   6.8              47
# 1624                   Baltic Porter             12 oz.   9.9              85
# 1836              American Brown Ale             16 oz.   5.9              47
# 1857           English Pale Mild Ale             12 oz.   4.5  Does not apply
# 1962         American Pale Ale (APA)             12 oz.   5.5  Does not apply
# 1970         American Pale Wheat Ale             16 oz.   5.2              11
# 1971          Saison / Farmhouse Ale             16 oz.   4.9              35
# 1972  American Double / Imperial IPA             12 oz.   9.1             103
# 2027    English India Pale Ale (IPA)             12 oz.   6.8              47
# 2062                  American Stout             16 oz.   6.3              69
# 2074                     Pumpkin Ale             16 oz.   6.0              48
# 2140                 German Pilsener             16 oz.   5.4              42
# 2141                       Cream Ale             16 oz.   5.2              34
# 2142                        Rye Beer             16 oz.   6.3              57
# 2143                    American IPA             16 oz.   6.4              62
# 2219           English Pale Mild Ale             12 oz.   4.5  Does not apply
# 2350      American Amber / Red Lager             16 oz.   5.2  Does not apply
# 2351      American Amber / Red Lager             12 oz.   5.2  Does not apply

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df.Location == 'Brooklyn, NY'].sort_values(by='Beer').max()
# Out:
# Beer              The Crisp (2011)
# Brewery        Sixpoint Craft Ales
# Location              Brooklyn, NY
# Style       Saison / Farmhouse Ale
# Size             24 oz. "Silo Can"
# ABV                             10
# IBUs                Does not apply
# dtype: object

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df.Brewery == 'Sixpoint Craft Ales'].sort_values(by='Beer').head(5)
# Out:
#                               Beer              Brewery      Location  \
# 1624                        3Beans  Sixpoint Craft Ales  Brooklyn, NY
# 115                         4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 246                        Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 1970                        Apollo  Sixpoint Craft Ales  Brooklyn, NY
# 2074  Autumnation (2011-12) (2011)  Sixpoint Craft Ales  Brooklyn, NY
#
#                         Style    Size   ABV            IBUs
# 1624            Baltic Porter  12 oz.   9.9              85
# 115             Baltic Porter  12 oz.  10.0              52
# 246          Belgian Pale Ale  12 oz.   8.0  Does not apply
# 1970  American Pale Wheat Ale  16 oz.   5.2              11
# 2074              Pumpkin Ale  16 oz.   6.0              48

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df.Location.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2386    False
# 2387    False
# 2388    False
# 2389    False
# 2390    False
# 2391    False
# 2392    False
# 2393    False
# 2394    False
# 2395    False
# 2396    False
# 2397    False
# 2398    False
# 2399    False
# 2400    False
# 2401    False
# 2402    False
# 2403    False
# 2404    False
# 2405    False
# 2406    False
# 2407    False
# 2408    False
# 2409    False
# 2410    False
# 2411    False
# 2412    False
# 2413    False
# 2414    False
# 2415    False
# Name: Location, Length: 2416, dtype: bool

# %%
df[df.Location.isna()]
# Out:
#                  Beer Brewery Location Style Size  ABV IBUs
# 2025           12 oz.     NaN      NaN   NaN  NaN  NaN  NaN
# 2160         (24 oz.)     NaN      NaN   NaN  NaN  NaN  NaN
# 2226         (12 oz.)     NaN      NaN   NaN  NaN  NaN  NaN
# 2276         (12 oz.)     NaN      NaN   NaN  NaN  NaN  NaN
# 2374  (16 oz.) (2010)     NaN      NaN   NaN  NaN  NaN  NaN
# 2376  (16 oz.) (2010)     NaN      NaN   NaN  NaN  NaN  NaN

# %%
#every time Location is missing data it adds 1 [False 0, True 1]
df.Location.isna().sum()
# Out:
# 6

# %%
df = df.dropna(subset=['Location'])

# %%
df[df.Location.isna()]
# Out:
# Empty DataFrame
# Columns: [Beer, Brewery, Location, Style, Size, ABV, IBUs]
# Index: []

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs         object
# dtype: object

# %%
df.Location.str.replace('NY', 'New York State')
df['Location'] = df.Location.str.replace('NY', 'New York State')

# %%
df[df.Location == 'New York State'].count()
# Out:
# Beer        0
# Brewery     0
# Location    0
# Style       0
# Size        0
# ABV         0
# IBUs        0
# dtype: int64

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %%
df[df.Style.str.contains('IPA', na=False)]
# Out:
#                                    Beer                          Brewery  \
# 0                          Get Together                NorthGate Brewing
# 6                        Citra Ass Down        Against the Grain Brewery
# 14                          Rico Sauvin        Against the Grain Brewery
# 17                         Pile of Face        Against the Grain Brewery
# 24                       Habitus (2014)        Mike Hess Brewing Company
# 25                                Solis        Mike Hess Brewing Company
# 27                              Habitus        Mike Hess Brewing Company
# 33                             Villager          Fort Point Beer Company
# 38                               HopArt            COAST Brewing Company
# 39                             Boy King            COAST Brewing Company
# 43                               Rumble     Great Divide Brewing Company
# 45                                Lasso     Great Divide Brewing Company
# 48                            Titan IPA     Great Divide Brewing Company
# 55                             Nordskye               Blackrocks Brewery
# 59    98 Problems (Cuz A Hop Ain't One)           Perrin Brewing Company
# 61                       Grapefruit IPA           Perrin Brewing Company
# 62                         Train Hopper      Witch's Hat Brewing Company
# 71                             Thai.p.a               Bare Hands Brewery
# 78                             The 26th             Four Fathers Brewing
# 79                           The Gadget             Four Fathers Brewing
# 86                           Galaxyfest        450 North Brewing Company
# 87                            Citrafest        450 North Brewing Company
# 89                           Gone A-Rye              Cedar Creek Brewery
# 92                   Linnaeus Mango IPA                   Brewery Vivant
# 93                        Heavy Lifting        Boulevard Brewing Company
# 96                   Grapefruit Sculpin    Ballast Point Brewing Company
# 97                          Liberty Ale           Anchor Brewing Company
# 93                  Kansas City, MO                    American IPA  12 oz.
# 96                    San Diego, CA                    American IPA  12 oz.
# 97                San Francisco, CA                    American IPA   12 oz
# 100                     Boulder, CO  American Double / Imperial IPA  12 oz.
# 104                 Murphysboro, IL                    American IPA  16 oz.
# 107              East Fairfield, VT                    American IPA  16 oz.
# ...                             ...                             ...     ...
# 2245                  Spearfish, SD                    American IPA  12 oz.
# 2248                   Santa Fe, NM                    American IPA  12 oz.
# 2252                     Denver, CO                    American IPA  12 oz.
# 2257                 Washington, DC                    American IPA  12 oz.
# 2261                   Lewiston, ME                    American IPA  12 oz.
# 2279                  Silverton, CO                    American IPA  12 oz.
# 2281                  Rochester, MI                    American IPA  16 oz.
# 2288                   Williams, AZ                    American IPA  12 oz.
# 2299                     Boston, MA                    American IPA  12 oz.
# 2306               Fort Collins, CO                    American IPA  12 oz.
# 2313                    Boulder, CO                    American IPA  12 oz.
# 2316                  Manhattan, KS  American Double / Imperial IPA  16 oz.
# 2319                  Manhattan, KS                    American IPA  16 oz.
# 2326                    Durango, CO                    American IPA  12 oz.
# 2330                   Missoula, MT                    American IPA  16 oz.
# 2337                    Boulder, CO                    American IPA  12 oz.
# 2341              Mammoth Lakes, CA                    American IPA  12 oz.
# 2349                    Durango, CO                    American IPA  12 oz.
# 2365  Garrattsville, New York State                    American IPA  12 oz.
# 2369                 Gig Harbor, WA  American Double / Imperial IPA  16 oz.
# 2375                 Woodbridge, CT  American Double / Imperial IPA  16 oz.
# 2379                 Woodbridge, CT                    American IPA  12 oz.
# 2382                    Ashland, OR                    American IPA  12 oz.
# 2387                    Lahaina, HI                    American IPA  12 oz.
# 2394                  Pottstown, PA                    American IPA  12 oz.
# 2403            Brooklyn Center, MN  American Double / Imperial IPA  16 oz.
# 2406            Brooklyn Center, MN                    American IPA  16 oz.
# 2408              San Francisco, CA                    American IPA  12 oz.
# 2412                   Longmont, CO  American Double / Imperial IPA  12 oz.
# 2414                   Longmont, CO  American Double / Imperial IPA  12 oz.
#
#       ABV            IBUs
# 0     4.5              50
# 6     8.0              68
# 14    7.6              68
# 17    6.0              65
# 24    8.0             100
# 25    7.5              85
# 27    8.0             100
# 33    6.3              42
# 38    7.7  Does not apply
# 39    9.7  Does not apply
# 43    7.1  Does not apply
# 45    5.0  Does not apply
# 48    7.1  Does not apply
# 55    4.8              47
# 59    6.5              65
# 61    5.0              35
# 62    5.8              72
# 71    7.0              46
# 78    6.0  Does not apply
# 79    6.4              90
# 86    6.5  Does not apply
# 87    5.0              45
# 89    8.5              90
# 92    6.0  Does not apply
# 93    6.2              80
# 96    7.0  Does not apply
# 97    5.9  Does not apply
# 100   8.0  Does not apply
# 104   7.5              60
# 107   5.5  Does not apply
# ...   ...             ...
# 2245  6.0  Does not apply
# 2248  6.6  Does not apply
# 2252  6.2              68
# 2257  6.5              80
# 2261  6.9              69
# 2279  6.8  Does not apply
# 2281  7.0  Does not apply
# 2288  NaN  Does not apply
# 2299  5.9              42
# 2306  6.5              70
# 2313  6.3              69
# 2316  7.2              93
# 2319  6.3              60
# 2326  6.5              65
# 2330  6.5              65
# 2337  7.2  Does not apply
# 2341  6.5  Does not apply
# 2349  6.8              65
# 2365  6.8  Does not apply
# 2369  8.4              82
# 2375  8.8              85
# 2379  6.2  Does not apply
# 2382  6.1              94
# 2387  6.2              65
# 2394  7.0             113
# 2403  9.7             120
# 2406  6.2              99
# 2408  7.0              65
# 2412  9.9             100
# 2414  8.7              85
#
# [571 rows x 7 columns]

# %%
df[df.Style.str.contains('IPA', na=False)].count()
# Out:
# Beer        571
# Brewery     571
# Location    571
# Style       571
# Size        571
# ABV         560
# IBUs        571
# dtype: int64

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df.IBUs
# Out:
# 0                   50
# 1                   26
# 2                   19
# 3                   38
# 4                   25
# 5                   47
# 6                   68
# 7                   80
# 8                   25
# 9                   42
# 10                  25
# 11                  21
# 12                  13
# 13                  17
# 14                  68
# 15                  38
# 16      Does not apply
# 17                  65
# 18                  20
# 19                  18
# 20                  15
# 21                  80
# 22                  65
# 23                  45
# 24                 100
# 25                  85
# 26                  24
# 27                 100
# 28                  30
# 29                  28
#              ...
# 2386                30
# 2387                65
# 2388    Does not apply
# 2389    Does not apply
# 2390                42
# 2391                35
# 2392                40
# 2393    Does not apply
# 2394               113
# 2395                21
# 2396                11
# 2397                44
# 2398                40
# 2399                37
# 2400                34
# 2401                45
# 2402                45
# 2403               120
# 2404                20
# 2405                33
# 2406                99
# 2407                35
# 2408                65
# 2409                17
# 2410                98
# 2411                35
# 2412               100
# 2413                35
# 2414                85
# 2415                65
# Name: IBUs, Length: 2410, dtype: object

# %%
df['IBUs'] = df.IBUs.replace('Does not apply', np.nan)
df.IBUs.astype(float)
df.IBUs.median()
# Out:
# 35.0

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# 1. Do the `.replace` and `np.nan` thing we did in class. Then convert the column to a number. This is boring.
# 2. When you're reading in your csv, there [is an option called `na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). You can give it a list of **numbers or strings to count as `NaN`**. It's a lot easier than doing the `np.nan` thing, although you'll need to go add it up top and run all of your cells again.
#
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %%
df.IBUs.median()
# Out:
# 35.0

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %%
df.IBUs.hist(bins=10)

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %%
# Out:
# count     1405
# unique     107
# top         20
# freq        82
# Name: IBUs, dtype: object

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %%
df.IBUs.sort_values()
# Out:
# 343      10
# 1502     10
# 2144     10
# 1477     10
# 1411     10
# 167      10
# 183      10
# 56       10
# 1771     10
# 1988     10
# 1979     10
# 999      10
# 2312     10
# 310      10
# 377      10
# 254      10
# 748      10
# 1109     10
# 274     100
# 2412    100
# 518     100
# 1966    100
# 1781    100
# 1216    100
# 110     100
# 1489    100
# 1046    100
# 372     100
# 584     100
# 1757    100
#        ...
# 2336    NaN
# 2337    NaN
# 2341    NaN
# 2342    NaN
# 2343    NaN
# 2344    NaN
# 2346    NaN
# 2347    NaN
# 2350    NaN
# 2351    NaN
# 2352    NaN
# 2353    NaN
# 2354    NaN
# 2355    NaN
# 2356    NaN
# 2357    NaN
# 2358    NaN
# 2359    NaN
# 2360    NaN
# 2364    NaN
# 2365    NaN
# 2366    NaN
# 2367    NaN
# 2373    NaN
# 2377    NaN
# 2378    NaN
# 2379    NaN
# 2388    NaN
# 2389    NaN
# 2393    NaN
# Name: IBUs, Length: 2410, dtype: object

# %%
groupby('Style')['IBUs'].medi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-242ca6d0cef9> in <module>
# ----> 1 groupby('Style')['IBUs'].median().sort_values(na_position='first').plot(kind='barh', figsize=('4, 30'))
#
# NameError: name 'groupby' is not defined

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %% [markdown]
# ## Plot those two histograms on top of one another
#
# To plot two plots on top of one another, you do two steps.
#
# 1. First, you make a plot using `plot` or `hist`, and you save it into a variable called `ax`.
# 2. You draw your second graph using `plot` or `hist`, and send `ax=ax` to it as a parameter.
#
# It would look something like this:
#
# ```python
# ax = df.plot(....)
# df.plot(ax=ax, ....)
# ```
#
# (...except totally different)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %% [markdown]
# ## Good work!
#
# If you made it this far you deserve a drink.
